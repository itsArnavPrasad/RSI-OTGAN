# %% [markdown]
# # Configuration and Imports

# %%
import os
import glob
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt

# --- Configuration ---
# Use 'mps' for Apple Silicon (M1/M2/M3) acceleration
DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using Device: {DEVICE}")

# Hyperparameters from the Paper
BATCH_SIZE = 4  # Adjust based on M1 RAM (8GB vs 16GB)
IMG_SIZE = 256  # Training patch size
LR = 0.0002
B1 = 0.5
B2 = 0.999
N_EPOCHS = 100
LAMBDA_OT = 3.0       # Optimal Transport Weight (Section 3.4)
LAMBDA_GP = 5.0       # Gradient Penalty Weight (Section 3.4)
NUM_CLASSES = 7       # LoveDA classes

# Paths
DATA_ROOT = "./data"
